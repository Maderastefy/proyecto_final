# %% [markdown]
# <a href="https://colab.research.google.com/github/Maderastefy/proyecto_final/blob/main/Preguntas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Ejemplo

import tensorflow as tf
import numpy as np

celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array ([-40, 14, 32, 46, 59, 72, 100], dtype=float)

capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

modelo.compile(optimizer=tf.keras.optimizers.Adam(0.1), loss="mean_squared_error")

print('comenzando entranamiento...')
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=True)
print("Modelo entrenado!")
# Out:
# comenzando entranamiento...
# Epoch 1/1000
# 1/1 [==============================] - 1s 1s/step - loss: 2133.5210
# Epoch 2/1000
# 1/1 [==============================] - 0s 21ms/step - loss: 1971.0823
# Epoch 3/1000
# 1/1 [==============================] - 0s 16ms/step - loss: 1820.3998
# Epoch 4/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 1681.6429
# Epoch 5/1000
# 1/1 [==============================] - 0s 17ms/step - loss: 1554.9230
# Epoch 6/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1440.2777
# Epoch 7/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1337.6635
# Epoch 8/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1246.9451
# Epoch 9/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1167.8796
# Epoch 10/1000
# 1/1 [==============================] - 0s 13ms/step - loss: 1100.1115
# Epoch 11/1000
# 1/1 [==============================] - 0s 12ms/step - loss: 1043.1609
# ...

# %%
print('hagamos una prediccion')
resultado = modelo.predict([100.0])
print('El resultado es' + str(resultado) + "fahrenheit")

print("variales internas del modelo")
print(capa.get_weights())
# Out:
# hagamos una prediccion
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-61c0c09b84ef> in <cell line: 2>()
#       1 print('hagamos una prediccion')
# ----> 2 resultado = modelo.predict([100.0])
#       3 print('El resultado es' + str(resultado) + "fahrenheit")
#       4
#       5 print("variales internas del modelo")
#
# NameError: name 'modelo' is not defined

# %%
#ecuacion de Fahrenheit

def F(C):
 return (C * 1.8) + 32

#definimos parametros
C = 100.00

print('El resultado es', F(C))

#Los resultados son casi iguales
#los valores de peso y sesgo obtenidos por la red son similares a los optenidos por la ecuacion.
# Out:
# El resultado es 212.0

# %%
#modificando la red

import tensorflow as tf
import numpy as np

oculta1 = tf.keras.layers.Dense(units=3, input_shape=[1])
oculta2 = tf.keras.layers.Dense(units=3)
salida = tf.keras.layers.Dense(units=1)
modelo = tf.keras.Sequential([oculta1, oculta2, salida])

modelo.compile(optimizer= tf.keras.optimizers.Adam(0.1), loss='mean_squared_error')

print("comenzamos entranamiento...")
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print('Modelo entrenado')

import matplotlib.pyplot as plt
plt.xlabel('# Epoca')
plt.ylabel('Magnitud de perdida')
plt.plot(historial.history['loss'])
# Out:
# comenzamos entranamiento...
# Modelo entrenado

# %%
print('Hagamos predicciones')
resultado = modelo.predict([100,00])
print('El resultado es' + str(resultado) + 'Fahrenheit')

print('Variables internas del modelo')
#print(capa.get_weights())
print(oculta1.get_weights())
print(oculta2.get_weights())
print(salida.get_weights())
# Out:
# Hagamos predicciones
# 1/1 [==============================] - 0s 405ms/step
# El resultado es[[211.74744 ]
#  [ 31.952524]]Fahrenheit
# Variables internas del modelo
# [array([[0.11147933, 0.65444326, 0.34112224]], dtype=float32), array([-3.293783 ,  4.4541316,  4.33739  ], dtype=float32)]
# [array([[ 0.01719571,  0.6760929 , -0.576291  ],
#        [-0.00527492, -1.265488  ,  0.02680736],
#        [ 0.7612099 , -0.6566964 , -0.20021431]], dtype=float32), array([ 2.3845491, -4.181086 , -2.276603 ], dtype=float32)]
# [array([[ 0.38000742],
#        [-1.7205577 ],
#        [-0.16660534]], dtype=float32), array([4.0100923], dtype=float32)]
